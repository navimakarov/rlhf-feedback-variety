# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt

# %%
"""
def get_valid_columns_df(df):
    return df[list(filter(lambda col: col == "Step" or (col[-3:] not in ("MAX", "MIN")), df.columns))]

wandb1 = get_valid_columns_df(pd.read_csv("wandb1.csv"))
wandb2 = get_valid_columns_df(pd.read_csv("wandb2.csv"))
wandb_merged_filtered = wandb1.merge(wandb2)
wandb_merged_filtered.columns = list(map(lambda col: col.split(" ")[0], wandb_merged_filtered.columns))
wandb_merged_filtered.to_csv("wandb_merged_filtered.csv", index=False)
"""

# %%
wandb = pd.read_csv("wandb_merged_filtered.csv")
prefixes = set(col.rsplit('_', 1)[0] for col in wandb.columns[1:])

grouped_data = {prefix: wandb.filter(like=prefix).values for prefix in prefixes}

grouped_df = pd.DataFrame({prefix: [list(grouped_data[prefix][i]) for i in range(len(wandb))] for prefix in prefixes})

# %%
def get_df_regexp_columns(df, regexp):
    pattern = re.compile(regexp)
    matched_columns = [col for col in df.columns if pattern.match(col)]
    return df[matched_columns]

# %%
grouped_df
# Out:
#                             Preference_Improved100_200  \
# 0    [-1421.135009765625, -1187.5355224609375, -111...
# 1    [-1242.6370849609375, -1220.106689453125, -114...
# 2    [-1269.213134765625, -1189.5648193359375, -116...
# 3    [-1244.529541015625, -1229.5927734375, -1158.2...
# 4    [-1230.720703125, -1190.05712890625, -1200.565...
# ..                                                 ...
# 240  [-231.568603515625, -257.1402587890625, -198.4...
# 241  [-229.5494384765625, -253.8411865234375, -190....
# 242  [-233.40870666503903, -245.6610107421875, -183...
# 243  [-240.44227600097656, -266.61328125, -178.4867...
# 244  [-241.0925750732422, -290.75286865234375, -183...
#
#                              Preference_Improved100_50  \
# 0    [-1421.135009765625, -1187.5355224609375, -111...
# 1    [-1236.8475341796875, -1222.0997314453125, -11...
# 2    [-1269.19970703125, -1193.118896484375, -1162....
# 3    [-1248.24072265625, -1229.7008056640625, -1161...
# 4    [-1245.0159912109375, -1188.318603515625, -119...
# ..                                                 ...
# 240  [-458.2472229003906, -187.32086181640625, -228...
# 241  [-464.4574279785156, -192.31930541992188, -247...
# 242  [-481.8187561035156, -190.91070556640625, -258...
# 243  [-496.06048583984375, -191.1232147216797, -279...
# 244  [-480.04547119140625, -198.68972778320312, -28...
#
#                                          MSE_Human_100  \
# 0    [-1421.135009765625, -1187.5355224609375, -111...
# 1    [-1242.00537109375, -1216.889892578125, -1136....
# 2    [-1271.437255859375, -1170.001953125, -1160.73...
# 3    [-1246.5687255859375, -1201.689208984375, -115...
# 4    [-1239.250732421875, -1165.279296875, -1194.48...
# ..                                                 ...
# 240  [-465.280029296875, -293.39373779296875, -189....
# 241  [-459.5408935546875, -319.1120910644531, -181....
# 242  [-488.95263671875, -303.4187316894531, -177.52...
# 243  [-498.37493896484375, -310.6432189941406, -172...
# 244  [-491.5245666503906, -348.2859191894531, -178....
#
#                                         Preference_100  \
# 0    [-1421.135009765625, -1187.5355224609375, -111...
# 1    [-1234.53515625, -1222.478759765625, -1152.525...
# 2    [-1261.704345703125, -1197.083251953125, -1175...
# 3    [-1233.990478515625, -1250.91259765625, -1172....
# 4    [-1223.5213623046875, -1222.7635498046875, -12...
# ..                                                 ...
# 240  [-248.2498016357422, -1142.465576171875, -253....
# 241  [-240.11585998535156, -1169.124267578125, -237...
# 242  [-244.2420959472656, -1151.367431640625, -231....
# 243  [-253.46026611328125, -1148.3583984375, -223.4...
# 244  [-251.1813201904297, -1159.7027587890625, -235...
#
#                                          Preference_50  \
# 0    [-1421.135009765625, -1187.5355224609375, -111...
# 1    [-
# [245 rows x 30 columns]

# %%
preference_df = get_df_regexp_columns(grouped_df, r"Preference_\d+")
preference_margin1_df = get_df_regexp_columns(grouped_df, r"Preference_Improved1_\d+")
preference_margin10_df = get_df_regexp_columns(grouped_df, r"Preference_Improved10_\d+")
preference_margin100_df = get_df_regexp_columns(grouped_df, r"Preference_Improved100_\d+")
mse_inaccurate_df = get_df_regexp_columns(grouped_df, r"MSE_Human_\d+")
mse_df = get_df_regexp_columns(grouped_df, r"Pendulum_MSE_\d+")
mse_df
# Out:
#                                       Pendulum_MSE_100  \
# 0    [-1421.135009765625, -1187.5355224609375, -111...
# 1    [-1234.98095703125, -1219.563720703125, -1134....
# 2    [-1264.9073486328125, -1195.4625244140625, -11...
# 3    [-1253.3424072265625, -1247.504638671875, -114...
# 4    [-1250.0093994140625, -1210.9102783203125, -11...
# ..                                                 ...
# 240  [-204.2279357910156, -160.7918701171875, -154....
# 241  [-194.18272399902344, -165.58509826660156, -14...
# 242  [-196.3268280029297, -165.33872985839844, -149...
# 243  [-210.39376831054688, -164.19288635253906, -14...
# 244  [-201.6427001953125, -166.75843811035156, -149...
#
#                                        Pendulum_MSE_50  \
# 0    [-1421.135009765625, -1187.5355224609375, -111...
# 1    [-1239.755126953125, -1218.588134765625, -1132...
# 2    [-1274.28125, -1194.770263671875, -1139.449096...
# 3    [-1263.7681884765625, -1250.3795166015625, -11...
# 4    [-1262.7164306640625, -1216.5911865234375, -11...
# ..                                                 ...
# 240  [-240.13604736328125, -188.8557586669922, -197...
# 241  [-236.9767303466797, -198.4542236328125, -192....
# 242  [-251.8397979736328, -200.73924255371097, -192...
# 243  [-256.4443054199219, -200.8863983154297, -187....
# 244  [-253.34942626953125, -217.48318481445312, -18...
#
#                                        Pendulum_MSE_10  \
# 0    [-1421.135009765625, -1187.5355224609375, -111...
# 1    [-1234.98095703125, -1219.563720703125, -1134....
# 2    [-1264.9073486328125, -1195.4625244140625, -11...
# 3    [-1253.3424072265625, -1247.504638671875, -114...
# 4    [-1250.0093994140625, -1210.9102783203125, -11...
# ..                                                 ...
# 240  [-204.2279357910156, -160.7918701171875, -154....
# 241  [-194.18272399902344, -165.58509826660156, -14...
# 242  [-196.3268280029297, -165.33872985839844, -149...
# 243  [-210.39376831054688, -164.19288635253906, -14...
# 244  [-201.6427001953125, -166.75843811035156, -149...
#
#                                        Pendulum_MSE_25  \
# 0    [-1421.135009765625, -1187.5355224609375, -111...
# 1    [-1234.7418212890625, -1219.439208984375, -113...
# 2    [-1270.22509765625, -1193.386474609375, -1141....
# 3    [-1253.5635986328125, -1240.26318359375, -1152...
# 4    [-1250.14404296875, -1203.6622314453125, -1198...
# ..                                                 ...
# 240  [-239.3059234619141, -273.929443359375, -187.2...
# 241  [-236.209716796875, -277.57757568359375, -172....
# 242  [-241.52999877929688, -276.3157043457031, -171...
# 243  [-249.76950073242188, -274.96331787109375, -16...
# 244  [-250.34893798828125, -284.59552001953125, -19...
#
#                                       Pendulum_MSE_200
# 0    [-1421.135009765625, -1187.5355224609375, -111...
# 1    [-1223.7213134765625, -1218.3720703125, -1133....
# 2    [-1252.3505859375, -1194.9185791015625, -1145....
# 3    [-1235.4952392578125, -1246.369873046875, -115...
# 4    [-1233.960205078125, -1210.595947265625, -1196...
# ..                                                 ...
# 240  [-175.05657958984375, -171.09762573242188, -15...
# 241  [-168.06600952148438, -181.1212921142578, -148...
# 242  [-168.947265625, -184.92633056640625, -148.894...
# 243  [-173.211669921875, -187.75588989257812, -145....
# 244  [-170.47024536132812, -196.84095764160156, -14...
#
# [245 rows x 5 columns]

# %%
plt.rc('font', size=14)         # controls default text sizes
plt.rc('axes', titlesize=18)    # fontsize of the axes title
plt.rc('axes', labelsize=16)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=14)   # fontsize of the tick labels
plt.rc('ytick', labelsize=14)   # fontsize of the tick labels
plt.rc('legend', fontsize=14)   # legend fontsize

# %%
import math
def plot_reward(df, include_std=False, save_location=None):
    df_copy = df.copy(deep=True)
    df_copy.columns = list(map(lambda col: str(int(re.findall(r'\d+', col)[-1])) + " synthetic queries", df_copy.columns))
    means = df_copy.applymap(lambda x: np.mean(x) if isinstance(x, list) else np.nan)

    # Think about using standard error instead
    # / math.sqrt(5) -> much nicer look
    stds = df_copy.applymap(lambda x: np.std(x) / math.sqrt(5) if isinstance(x, list) else np.nan)

    columns_sorted = sorted(df_copy.columns, key=lambda x: int(re.findall(r'\d+', x)[-1]))
    
    
    # Plot the mean values
    plt.figure(figsize=(12, 8))
    for column in columns_sorted:
        plt.plot(means.index * 2_000, means[column], label=column)
        if include_std:
            # do not highlight std of volatile runs
            #if not re.compile(r".*_(10|25)$").match(column):
            plt.fill_between(means.index * 2_000, means[column] - stds[column], means[column] + stds[column], alpha=0.2)
    
    plt.xlabel('Timestep', fontsize=14)
    plt.ylabel('Reward', fontsize=14)
    plt.legend()
    #plt.grid(True)
    
    # Save the plot as a PNG file
    if save_location is not None:
        plt.savefig(save_location)
    plt.show()
    plt.close()

# %%
plot_reward(mse_df, include_std=True, save_location="rlhf_mse.png")

# %%
plot_reward(mse_inaccurate_df, include_std=True, save_location="rlhf_approximate_mse.png")
# Out:
# /var/folders/th/9xhq_z9s043bb_ybjxvx30hm0000gn/T/ipykernel_41220/2115437661.py:5: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   means = df_copy.applymap(lambda x: np.mean(x) if isinstance(x, list) else np.nan)
# /var/folders/th/9xhq_z9s043bb_ybjxvx30hm0000gn/T/ipykernel_41220/2115437661.py:9: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   stds = df_copy.applymap(lambda x: np.std(x) / math.sqrt(5) if isinstance(x, list) else np.nan)

# %%
plot_reward(preference_df, include_std=True, save_location="rlhf_comparison_pendulum.png")
# Out:
# /var/folders/th/9xhq_z9s043bb_ybjxvx30hm0000gn/T/ipykernel_41220/541056270.py:5: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   means = df_copy.applymap(lambda x: np.mean(x) if isinstance(x, list) else np.nan)
# /var/folders/th/9xhq_z9s043bb_ybjxvx30hm0000gn/T/ipykernel_41220/541056270.py:8: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   stds = df_copy.applymap(lambda x: np.std(x) / math.sqrt(5) if isinstance(x, list) else np.nan)

# %%
plot_reward(preference_margin1_df, include_std=True)

# %%
plot_reward(preference_margin10_df, include_std=True)

# %%
plot_reward(preference_margin100_df, include_std=True, save_location="rlhf_marginal_comparison_pendulum.png")
# Out:
# /var/folders/th/9xhq_z9s043bb_ybjxvx30hm0000gn/T/ipykernel_41220/2115437661.py:5: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   means = df_copy.applymap(lambda x: np.mean(x) if isinstance(x, list) else np.nan)
# /var/folders/th/9xhq_z9s043bb_ybjxvx30hm0000gn/T/ipykernel_41220/2115437661.py:9: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   stds = df_copy.applymap(lambda x: np.std(x) / math.sqrt(5) if isinstance(x, list) else np.nan)
